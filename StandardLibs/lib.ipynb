# %%
import math
math.ceil(8.8)
math.fabs(-10)
math.sqrt(25)       # 5.0
math.pow(2, 3)      # 8.0
math.floor(4.8)     # 4
math.ceil(4.2)      # 5
math.fabs(-10)      # 10.0
math.pi
math.e
math.factorial(3)
math.gcd(12, 14)
# Out:
# 2

# %%
import random
random.randint(9, 145)
random.random()

names = ['a', 'b', 'c']
random.choice(names)
random.shuffle(names)
names
# Out:
# ['a', 'c', 'b']

# %%
from datetime import datetime, date, timedelta

now = datetime.now()
now
now.date()
now.hour
now.year
now.month
now.second


today = date(2026, 9, 18)
today
# Out:
# datetime.date(2026, 9, 18)

# %%
from datetime import timedelta
today = date(2026, 9, 18)
tomorrow = today + timedelta(days=1)
tomorrow

d1 = date(2026, 9, 18)
d2 = date(2026, 9, 20)

d2 - d1
# Out:
# datetime.timedelta(days=2)

# %%
from collections import Counter
nums = [1, 2, 2, 1, 5, 6] #Very useful for frequency counting.
count = Counter(nums)
count
# Out:
# Counter({1: 2, 2: 2, 5: 1, 6: 1})

# %%
from collections import defaultdict
# Dictionary with a default value.
d = defaultdict(int)

d["apple"] += 1

d


groups = defaultdict(list)

groups["A"].append(10)
groups["A"].append(20)
groups
# Out:
# defaultdict(list, {'A': [10, 20]})

# %%
from collections import deque
q = deque()

q.append(10)
q.append(20)
q 
# q.pop()  10
q.popleft()  #20
q
# Out:
# deque([20])

# %%
import itertools
a = [1,2]
b = [3,4]

list(itertools.chain(a, b))
# Out:
# [1, 2, 3, 4]

# %%
from itertools import combinations
#Generate combinations.
nums = [1, 2, 3]

print(list(combinations(nums, 2)))
# Out:
# [(1, 2), (1, 3), (2, 3)]

# %%
from itertools import permutations

print(list(permutations([1, 2, 3], 2)))
# Out:
# [(1, 2), (1, 3), (2, 1), (2, 3), (3, 1), (3, 2)]

# %%
import sys
sys.version
sys.argv
sys.exit()
# Out:
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit
# C:\Users\ABHILASH\AppData\Roaming\Python\Python314\site-packages\IPython\core\interactiveshell.py:3831: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
